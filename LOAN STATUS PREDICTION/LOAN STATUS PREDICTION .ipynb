# %% [markdown]
# # LOAN STATUS PREDICTION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("train_u6lujuX_CVtuZ9i (1).csv")

# %%
 df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
print("Loan_ID: ",df['Loan_ID'].value_counts())
print("--------------------------------------")
print("Gender: ",df['Gender'].value_counts())
print("--------------------------------------")
print(" Married: ",df['Married'].value_counts())
print("--------------------------------------")
print("Dependents: ",df['Dependents'].value_counts())
print("--------------------------------------")
print("Education: ",df['Education'].value_counts())
print("--------------------------------------")
print("Self_Employed: ",df['Self_Employed'].value_counts())
print("--------------------------------------")
print("ApplicantIncome: ",df['ApplicantIncome'].value_counts())
print("--------------------------------------")
print("CoapplicantIncome: ",df['CoapplicantIncome'].value_counts())
print("--------------------------------------")
print("LoanAmount: ",df['LoanAmount'].value_counts())
print("--------------------------------------")
print("Loan_Amount_Term: ",df['Loan_Amount_Term'].value_counts())
print("--------------------------------------")
print("Credit_History: ",df['Credit_History'].value_counts())
print("--------------------------------------")
print("Property_Area: ",df['Property_Area'].value_counts())
print("--------------------------------------")
print("Loan_Status: ",df['Loan_Status'].value_counts())
# Out:
# Loan_ID:  Loan_ID
# LP001002    1
# LP002328    1
# LP002305    1
# LP002308    1
# LP002314    1
#            ..
# LP001692    1
# LP001693    1
# LP001698    1
# LP001699    1
# LP002990    1
# Name: count, Length: 614, dtype: int64
# --------------------------------------
# Gender:  Gender
# Male      489
# Female    112
# Name: count, dtype: int64
# --------------------------------------
#  Married:  Married
# Yes    398
# No     213
# Name: count, dtype: int64
# --------------------------------------
# Dependents:  Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64
# --------------------------------------
# Education:  Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64
# --------------------------------------
# Self_Employed:  Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64
# --------------------------------------
# ApplicantIncome:  ApplicantIncome
# 2500    9
# 4583    6
# 6000    6
# ...

# %%
print(df.columns)
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
# checking the value counts of all the cloumns using loop
columns = ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
           'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term',
           'Credit_History', 'Property_Area', 'Loan_Status']

for col in columns:
    print(f"{col}:\n{df[col].value_counts()}\n")
    print("--------------------------------------")
# Out:
# Loan_ID:
# Loan_ID
# LP001002    1
# LP002328    1
# LP002305    1
# LP002308    1
# LP002314    1
#            ..
# LP001692    1
# LP001693    1
# LP001698    1
# LP001699    1
# LP002990    1
# Name: count, Length: 614, dtype: int64
#
# --------------------------------------
# Gender:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64
#
# --------------------------------------
# Married:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64
#
# --------------------------------------
# Dependents:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64
#
# --------------------------------------
# Education:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64
#
# --------------------------------------
# Self_Employed:
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64
#
# --------------------------------------
# ApplicantIncome:
# ApplicantIncome
# 2500    9
# 4583    6
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.shape
# Out:
# (614, 13)

# %%
print("the Number of rows :", df.shape[0])
print("the Number of rows :", df.shape[1])
# Out:
# the Number of rows : 614
# the Number of rows : 13

# %%
df.isnull().sum()*100 / len(df) # percentage of null values
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
# drop all null value
# --------------------------------------------
# df.dropna(inplace=True)
# df.isnull().sum()
# print(df.shape)
# print("the Number of rows :", df.shape[0])
# print("the Number of rows :", df.shape[1])

# %%
columns_data = ['Gender' , 'Dependents' , 'LoanAmount', 'Loan_Amount_Term']

data = df.dropna(subset = columns_data)
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        30
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       48
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Self_Employed'].unique() # yes or no hence mode() is used
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
columns = ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
           'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term',
           'Credit_History', 'Property_Area', 'Loan_Status']

for col in columns:
    print(f"{col}:\n{df[col].unique()}\n")
    print(f"--------------------------------------")
# Out:
# Loan_ID:
# ['LP001002' 'LP001003' 'LP001005' 'LP001006' 'LP001008' 'LP001011'
#  'LP001013' 'LP001014' 'LP001018' 'LP001020' 'LP001024' 'LP001027'
#  'LP001028' 'LP001029' 'LP001030' 'LP001032' 'LP001034' 'LP001036'
#  'LP001038' 'LP001041' 'LP001043' 'LP001046' 'LP001047' 'LP001050'
#  'LP001052' 'LP001066' 'LP001068' 'LP001073' 'LP001086' 'LP001087'
#  'LP001091' 'LP001095' 'LP001097' 'LP001098' 'LP001100' 'LP001106'
#  'LP001109' 'LP001112' 'LP001114' 'LP001116' 'LP001119' 'LP001120'
#  'LP001123' 'LP001131' 'LP001136' 'LP001137' 'LP001138' 'LP001144'
#  'LP001146' 'LP001151' 'LP001155' 'LP001157' 'LP001164' 'LP001179'
#  'LP001186' 'LP001194' 'LP001195' 'LP001197' 'LP001198' 'LP001199'
#  'LP001205' 'LP001206' 'LP001207' 'LP001213' 'LP001222' 'LP001225'
#  'LP001228' 'LP001233' 'LP001238' 'LP001241' 'LP001243' 'LP001245'
#  'LP001248' 'LP001250' 'LP001253' 'LP001255' 'LP001256' 'LP001259'
#  'LP001263' 'LP001264' 'LP001265' 'LP001266' 'LP001267' 'LP001273'
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
# fill the null values using fillna()

df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# removing the remaning column using dropna
columns_data = ['Gender' , 'Dependents' , 'LoanAmount', 'Loan_Amount_Term']

df = df.dropna(subset = columns_data)
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# ## HAndling categorical column

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 553 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            553 non-null    object
#  1   Gender             553 non-null    object
#  2   Married            553 non-null    object
#  3   Dependents         553 non-null    object
#  4   Education          553 non-null    object
#  5   Self_Employed      553 non-null    object
#  6   ApplicantIncome    553 non-null    int64
#  7   CoapplicantIncome  553 non-null    float64
#  8   LoanAmount         553 non-null    float64
#  9   Loan_Amount_Term   553 non-null    float64
#  10  Credit_History     553 non-null    float64
#  11  Property_Area      553 non-null    object
#  12  Loan_Status        553 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 60.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.sample(5)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 92   LP001319    Male     Yes          2  Not Graduate            No
# 504  LP002619    Male     Yes          0  Not Graduate            No
# 520  LP002689    Male     Yes          2  Not Graduate            No
# 510  LP002637    Male      No          0  Not Graduate            No
# 145  LP001514  Female     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 92              3273             1820.0        81.0             360.0
# 504             3814             1483.0       124.0             300.0
# 520             2192             1742.0        45.0             360.0
# 510             3598             1287.0       100.0             360.0
# 145             2330             4486.0       100.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 92              1.0         Urban           Y
# ...

# %%
df['Dependents'] = df['Dependents'].replace('3+',value = '4')
# Out:
# C:\Users\SIDDHARTH LUMAR\AppData\Local\Temp\ipykernel_21340\2478058420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dependents'] = df['Dependents'].replace('3+',value = '4')

# %%
df['Dependents'].unique()
# Out:
# array(['1', '0', '2', '4'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'] = df['Gender'].map({'Male' : 1 , 'Female' : 0}).astype('int')
# Out:
# C:\Users\SIDDHARTH LUMAR\AppData\Local\Temp\ipykernel_21340\3638822002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].map({'Male' : 1 , 'Female' : 0}).astype('int')

# %%
df['Loan_Status'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df['Married'] = df['Married'].map({'Yes' : 1 , 'No' : 0}).astype('int')
df['Education'] = df['Education'].map({'Graduate' : 1 , 'Not Graduate' : 0}).astype('int')
df['Self_Employed'] = df['Self_Employed'].map({'Yes' : 1 , 'No' : 0}).astype('int')
df['Property_Area'] = df['Property_Area'].map({'Rural' : 0 , 'Semiurban' : 1, 'Urban' : 2}).astype('int')
df['Loan_Status'] = df['Loan_Status'].map({'Y' : 1 , 'N' : 0}).astype('int')
# Out:
# C:\Users\SIDDHARTH LUMAR\AppData\Local\Temp\ipykernel_21340\1798581968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Married'] = df['Married'].map({'Yes' : 1 , 'No' : 0}).astype('int')
# C:\Users\SIDDHARTH LUMAR\AppData\Local\Temp\ipykernel_21340\1798581968.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Education'] = df['Education'].map({'Graduate' : 1 , 'Not Graduate' : 0}).astype('int')
# ...

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1  LP001003       1        1          1          1              0
# 2  LP001005       1        1          0          1              1
# 3  LP001006       1        1          0          0              0
# 4  LP001008       1        0          0          1              0
# 5  LP001011       1        1          2          1              1
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 1             1.0              0            0
# 2             1.0              2            1
# ...

# %% [markdown]
# # feature scaling and Spliting the Data

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1  LP001003       1        1          1          1              0
# 2  LP001005       1        1          0          1              1
# 3  LP001006       1        1          0          0              0
# 4  LP001008       1        0          0          1              0
# 5  LP001011       1        1          2          1              1
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 1             1.0              0            0
# 2             1.0              2            1
# ...

# %%
cols = ['ApplicantIncome' , 'CoapplicantIncome', 'LoanAmount' , 'Loan_Amount_Term']
scaler = StandardScaler()
df[cols] = scaler.fit_transform(df[cols])
df.head()
# Out:
# C:\Users\SIDDHARTH LUMAR\AppData\Local\Temp\ipykernel_21340\114230412.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cols] = scaler.fit_transform(df[cols])
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1  LP001003       1        1          1          1              0
# 2  LP001005       1        1          0          1              1
# 3  LP001006       1        1          0          0              0
# 4  LP001008       1        0          0          1              0
# 5  LP001011       1        1          2          1              1
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1        -0.128694          -0.049699   -0.214368          0.279961
# ...

# %%
x = df.drop(['Loan_Status' ,'Loan_ID']  ,axis=1)
y = df['Loan_Status']

# %% [markdown]
# ## Model Evaluation using function

# %%
# function
Model_Score = {}
Model_score_Precentage = {}


def model_val(Model , x, y):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
    Model.fit(x_train, y_train)
    y_pred = Model.predict(x_test)
    print(f'{Model} \nAccuracy score :' , accuracy_score(y_test, y_pred))
    
    score = cross_val_score(Model, x, y, cv=10)
    print(f'{Model}\n Average Cross Validation Score :', np.mean(score))
    Model_Score[Model] = np.mean(score)
    Model_score_Precentage[Model] = round(np.mean(score)*100)

# %% [markdown]
# ## Logistic Regression

# %%
x.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       1        1          1          1              0        -0.128694
# 2       1        1          0          1              1        -0.394296
# 3       1        1          0          0              0        -0.464262
# 4       1        0          0          1              0         0.109057
# 5       1        1          2          1              1         0.011239
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1          -0.049699   -0.214368          0.279961             1.0
# 2          -0.545638   -0.952675          0.279961             1.0
# 3           0.229842   -0.309634          0.279961             1.0
# 4          -0.545638   -0.059562          0.279961             1.0
# 5           0.834309    1.440866          0.279961             1.0
#
#    Property_Area
# 1              0
# 2              2
# 3              2
# 4              2
# 5              2

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model_val(model , x, y)
# Out:
# LogisticRegression()
# Accuracy score : 0.7747747747747747
# LogisticRegression()
#  Average Cross Validation Score : 0.8066233766233767

# %% [markdown]
# # SVM

# %%
from sklearn import svm

model = svm.SVC()
model_val(model , x, y)
# Out:
# SVC()
# Accuracy score : 0.8288288288288288
# SVC()
#  Average Cross Validation Score : 0.7956818181818182

# %% [markdown]
# # Decission Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model_val(model , x, y)
# Out:
# DecisionTreeClassifier()
# Accuracy score : 0.7207207207207207
# DecisionTreeClassifier()
#  Average Cross Validation Score : 0.6854220779220779

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model_val(model , x, y)
# Out:
# RandomForestClassifier()
# Accuracy score : 0.7927927927927928
# RandomForestClassifier()
#  Average Cross Validation Score : 0.7903246753246753

# %% [markdown]
# # GRADIENT BOOSTING CLASSIFIER

# %%
from sklearn.ensemble import GradientBoostingClassifier

model = GradientBoostingClassifier()
model_val(model , x, y)
# Out:
# GradientBoostingClassifier()
# Accuracy score : 0.7927927927927928
# GradientBoostingClassifier()
#  Average Cross Validation Score : 0.7831168831168831

# %% [markdown]
# # HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# ## Logistic Regression

# %%
log_param_grid = {
    "C":np.logspace(-4,4,20),
    "solver" : ['liblinear']
}

randomized_log_param_grid = RandomizedSearchCV(
    LogisticRegression(),
    param_distributions = log_param_grid ,
    n_iter = 20,
    cv = 5 
)

# %%
randomized_log_param_grid.fit(x,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(), n_iter=20,
#                    param_distributions={'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                                         'solver': ['liblinear']})

# %%
randomized_log_param_grid.best_score_
# Out:
# 0.802964782964783

# %%
randomized_log_param_grid.best_params_
# Out:
# {'solver': 'liblinear', 'C': 0.23357214690901212}

# %% [markdown]
# ## SVC

# %%
svc_grid = {'C':[0.25,0.50,0.75,1],"kernel":["linear"]}
rs_svc=RandomizedSearchCV(svm.SVC(),
                  param_distributions=svc_grid,
                   cv=5,
                   n_iter=20,
                  verbose=True)

rs_svc.fit(x,y)
# Out:
# C:\Users\SIDDHARTH LUMAR\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 4 is smaller than n_iter=20. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# RandomizedSearchCV(cv=5, estimator=SVC(), n_iter=20,
#                    param_distributions={'C': [0.25, 0.5, 0.75, 1],
#                                         'kernel': ['linear']},
#                    verbose=True)

# %%
rs_svc.best_score_
# Out:
# 0.8066011466011467

# %%
rs_svc.best_params_
# Out:
# {'kernel': 'linear', 'C': 0.25}

# %% [markdown]
# ## Random Forest Classifier

# %%
rf_grid={'n_estimators':np.arange(10,1000,10),
  'max_features':['auto','sqrt'],
 'max_depth':[None,3,5,10,20,30],
 'min_samples_split':[2,5,20,50,100],
 'min_samples_leaf':[1,2,5,10]
 }

rs_rf=RandomizedSearchCV(RandomForestClassifier(),
                  param_distributions=rf_grid,
                   cv=5,
                   n_iter=20,
                  verbose=True)

rs_rf.fit(x,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\Users\SIDDHARTH LUMAR\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 30 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\SIDDHARTH LUMAR\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\SIDDHARTH LUMAR\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
# ...

# %%
rs_rf.best_score_
# Out:
# 0.8084193284193285

# %%
rs_rf.best_params_
# Out:
# {'n_estimators': 360,
#  'min_samples_split': 20,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 3}
